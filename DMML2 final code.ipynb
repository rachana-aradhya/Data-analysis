# %%
import pandas as pd

# %%
#loading the dataset

df= pd.read_csv("C:\\Users\\sabre\\Downloads\\heart_failure_clinical_records_dataset.csv")

# %%
# preview the dataset

df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
#shape of the dataset

df.shape
# Out:
# (299, 13)

# %%
#EDA

df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.size
# Out:
# 3887

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.skew()
# Out:
# age                         0.423062
# anaemia                     0.278261
# creatinine_phosphokinase    4.463110
# diabetes                    0.333929
# ejection_fraction           0.555383
# high_blood_pressure         0.626732
# platelets                   1.462321
# serum_creatinine            4.455996
# serum_sodium               -1.048136
# sex                        -0.626732
# smoking                     0.770349
# time                        0.127803
# DEATH_EVENT                 0.770349
# dtype: float64

# %%
#CHECKING FOR DUPLICATE VALUES

df.duplicated().sum()
# Out:
# 0

# %%
# Verifying the Missing Values

df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
#There are no missing values in any of the columns
#Every column has dtype of either int64 or float64. 
#Though, some columns here like anaemia, sex, smoking are actually categorical in nature

# %%
#Describing the columns to gain more insights about what their values represent:

#age: The age of the person
#anaemia: Decrease of red blood cells or hemoglobin (boolean)
#creatinine_phosphokinase: Level of the CPK enzyme in the blood (mcg/L)
#diabetes: If the patient has diabetes (boolean)
#ejection_fraction: Percentage of blood leaving the heart at each contraction (percentage)
#high_blood_pressure: If the patient has hypertension (boolean)
#platelets: Platelets in the blood (kiloplatelets/mL)
#serum_creatinine: Level of serum creatinine in the blood (mg/dL)
#serum_sodium: Level of serum sodium in the blood (mEq/L)
#sex: Woman or man (binary)
#smoking: If the patient smokes or not (boolean)
#time: Follow-up period (days)
#DEATH_EVENT: If the patient deceased during the follow-up period (boolean)

# %%
import numpy as np # linear algebra



# Library for Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# For Warnings
import warnings
def warns(*args,**kwargs): pass
warnings.warn=warns

# %%
# Verify the Records of Dataset

print('='*25, ' COLUMNS ', '='*25)
print(df.columns)
print('\n')
df.head()
# Out:
# =========================  COLUMNS  =========================
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# ...

# %%
# Updating Data of the Selected Features


df['age'] = df['age'].round(1)
df['platelets'] = df['platelets'].round(2)
df['serum_creatinine'] = df['serum_creatinine'].round(2)

df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
# Selecting the Features


features = df.columns
print("Features Length: ", len(features))
features
# Out:
# Features Length:  13
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
# Verifying Number of Death Event

df['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
#The above output shows that Deaths events are 96 and 203 survived out of 299

# %%
#Number of Death Events


df_death = df[df['DEATH_EVENT'] == 1]
print(df_death.shape)
df_death.head()
# Out:
# (96, 13)
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
#Data Visualization

# %%
# CountPlot Function for Dataset Features of DEATH EVENT Only

def features_countplot(xAxis, xdf):
    plt.figure(figsize=(16,6)) # Width, Height
    ax = sns.countplot(x = xAxis, data=xdf)
    ax.bar_label(ax.containers[0])
    plt.xticks(rotation=90)
    
    xtitle = xAxis.replace('_', ' ').title()
    plt.title(xtitle + " In Death Events", fontsize = 24)
    plt.xlabel(xtitle + " Level", fontsize = 14)

# %%
# CountPlot Function of Full Dataset Features
def features_countplot_hue(xAxis, xdf):
    plt.figure(figsize=(16,6)) # Width, Height
    ax = sns.countplot(x = xAxis, data=xdf, hue='DEATH_EVENT')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    plt.xticks(rotation=90)
    
    plt.legend(title='Death Event', loc='upper right', labels=['Survived', 'Died'])
    
    xtitle = xAxis.replace('_', ' ').title()
    plt.title("Comparison of Death & Survived Cases and " + xtitle, fontsize = 24)
    plt.xlabel(xtitle + " Level", fontsize = 14)

# %%
#Visualization Analysis - Only For Death Events

for x in features[:-1]:
    features_countplot(x, df_death)

# %%
#Relation of Age, Death Events With All Other Features

# %%
# for visualizations
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Setting some styles
sns.set_style("darkgrid")
sns.set_palette("viridis")

# %%
# for subplots
def subplts(r=1, c=1, fs=(20, 8)):
    return plt.subplots(r, c, figsize=fs)

# count plot
def plot_count(x, ax, d=df):
    sns.countplot(data=d, x=x, ax=ax)

# histogram without hue
def plot_hist(x, ax, d=df, kde=True, log=False):
    sns.histplot(data=d, x=x, ax=ax, kde=kde, log_scale=log)

# histogram with hue
def plot_hist_hue(x, hu, ax, d=df, multi="stack", kde=True, log=False):
    sns.histplot(data=d, x=x, ax=ax, hue=hu, kde=kde, multiple=multi, log_scale=log)
    
# boxplot single
def plot_box(x, ax, d=df):
    sns.boxplot(data=d, x=x, ax=ax)
    
# boxplot with one categorical
def plot_boxcat(x, y, ax, d=df):
    sns.boxplot(data=d, x=x, y=y, ax=ax)
    
# pie chart using pandas
def plot_pie(feat, ax, title):
    df[f"{feat}"].value_counts().plot.pie(ax=ax, autopct="%1.1f%%",
                                          shadow=True, explode=[0, 0.1]).set_title(f"{title}")

# %%
#Univariate Analysis
#Analysis of Age

#Since age is a continuous variable

fig, ax = subplts(1, 2)

plot_hist("age", ax[0])
plot_box("age", ax[1])

plt.show()

# %%
df["age"].value_counts().head()
# Out:
# 60.0    33
# 50.0    27
# 65.0    26
# 70.0    25
# 45.0    19
# Name: age, dtype: int64

# %%
#We see that:

#Minimum age recorded in this dataset is 40 years
#Maximum age is 95 years
#Most people are 60 years old in this dataset

# %%
#Analysis of Anaemia

fig, ax = subplts(1, 2)

plot_count("anaemia", ax[0])
plot_pie("anaemia", ax[1], "Patient has anaemia?")

plt.show()

# %%
#We see that

#56.9% of people do not have anaemia (count 160+)
#43.1% of people has anaemia (count 120+)

# %%
#Analysis of Diabetes

fig, ax = subplts(1, 2)

plot_count("diabetes", ax[0])
plot_pie("diabetes", ax[1], "Patient has diabetes?")

plt.show()

# %%
#We see that

#58.2% of people are NOT diabetic (count 170+)
#Rest 41.8% people have diabetes (count 120+)

# %%
#Analysis on High Blood Pressure

fig, ax = subplts(1, 2)

plot_count("high_blood_pressure", ax[0])
plot_pie("high_blood_pressure", ax[1], "Patient has high blood pressure?")

plt.show()

# %%
#We see that,

#64.9% people do not have High Blood Pressure (count 160+)
#35.1% have high blood pressure (count 100+)

# %%
#Analysis of Smoking

fig, ax = subplts(1, 2)

plot_count("smoking", ax[0])
plot_pie("smoking", ax[1], "Patient is a smoker?")

plt.show()

# %%
#We see that in this dataset,

#67.9% people do not smoke
#Rest 32.1% people are smokers

# %%
#Analysis of Time (follow-up period)

fig, ax = subplts(1, 2)

plot_hist("time", ax[0])
plot_box("time", ax[1])

plt.show()

# %%
#We get to see that,

#Minimum time (follow-up period) is 4 days
#Median time (follow-up period) is 100+ days

# %%
#Analysis of DEATH_EVENT

#DEATH_EVENT is a binary categorical feature, which tells whether a patient died due to heart failure or not.

# %%
fig, ax = subplts(1, 2)

plot_count("DEATH_EVENT", ax[0])
plot_pie("DEATH_EVENT", ax[1], "Did the person die?")

plt.show()

# %%
#As we see

#67.9% of people did NOT die
#32.1% people died

# %%
#Multivariate Analysis

#Analysis of Age and DEATH_EVENT

# %%
fig, ax = subplts()

plot_hist_hue("age", "DEATH_EVENT", ax)
plt.show()

# %%
#We observe that for older ages, more number of patients have died. Let's check this by querying the DataFrame for the same.

# %%
death_age_sums = []

for age in range(40, 100):
    num_surr = df[(df["age"] == age) & (df["DEATH_EVENT"] == 0)].shape[0]
    num_died = df[(df["age"] == age) & (df["DEATH_EVENT"] == 1)].shape[0]
    
    if num_died != 0 and num_surr != 0 and num_died > num_surr:
        dic = {age: [num_died, num_surr]}
        death_age_sums.append(dic)
    
death_age_sums
# Out:
# [{59: [3, 1]},
#  {69: [2, 1]},
#  {72: [5, 2]},
#  {75: [6, 5]},
#  {80: [5, 2]},
#  {90: [2, 1]}]

# %%
#After the age of 70 years there are more people who died than people who survived,
#which is logical since with age, heart failure rate increases.

# %%
#Analysis of diabetes, high_blood_pressure, sex and smoking vs DEATH_EVENT

# %%
df1 = df[(df["diabetes"] == 0) & (df["DEATH_EVENT"] == 1)]
df2 = df[(df["diabetes"] == 1) & (df["DEATH_EVENT"] == 1)]
comb1 = pd.concat([df1, df2])

df3 = df[(df["high_blood_pressure"] == 0) & (df["DEATH_EVENT"] == 1)]
df4 = df[(df["high_blood_pressure"] == 1) & (df["DEATH_EVENT"] == 1)]
comb2 = pd.concat([df3, df4])

df5 = df[(df["sex"] == 0) & (df["DEATH_EVENT"] == 1)]
df6 = df[(df["sex"] == 1) & (df["DEATH_EVENT"] == 1)]
comb3 = pd.concat([df5, df6])

df7 = df[(df["smoking"] == 0) & (df["DEATH_EVENT"] == 1)]
df8 = df[(df["smoking"] == 1) & (df["DEATH_EVENT"] == 1)]
comb4 = pd.concat([df7, df8])

# %%
fig, ax = subplts(2, 2)

comb1["diabetes"].value_counts().plot.pie(ax=ax[0, 0], autopct="%1.1f%%", explode=[0, 0.1], shadow=True).set_title("Diabetes?")
comb2["high_blood_pressure"].value_counts().plot.pie(ax=ax[0, 1], autopct="%1.1f%%", explode=[0, 0.1], shadow=True).set_title("High Blood Pressure")
comb3["sex"].value_counts().plot.pie(ax=ax[1, 0], autopct="%1.1f%%", explode=[0, 0.1], shadow=True).set_title("Gender")
comb4["smoking"].value_counts().plot.pie(ax=ax[1, 1], autopct="%1.1f%%", explode=[0, 0.1], shadow=True).set_title("Smoker?")

plt.show()

# %%
#Analysis of time and DEATH_EVENT

fig, ax = subplts(2, 1, fs=(20, 15))

plot_hist_hue("time", "DEATH_EVENT", ax[0])
sns.violinplot(data=df, x="DEATH_EVENT", y="time", ax=ax[1])

plt.show()

# %%
#We clearly observe the pattern, the lesser the follow-up period (time feature) the greater the deaths, on an average. 
#Whereas, if the follow-up period is more, the person is more likely to survive. 
#time is linearly correlated with death, negatively.

# %%
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import GridSearchCV
def compute(Y_pred,Y_test):
    #Output plot
    plt.figure(figsize=(12,6))
    plt.scatter(range(len(Y_pred)),Y_pred,color="yellow",lw=5,label="Predictions")
    plt.scatter(range(len(Y_test)),Y_test,color="red",label="Actual")
    plt.title("Prediction Values vs Real Values")
    plt.legend()
    plt.show()

    cm=confusion_matrix(Y_test,Y_pred)
    class_label = ["High-risk", "Low-risk"]
    df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
    sns.heatmap(df_cm,annot=True,cmap='Pastel1',linewidths=2,fmt='d')
    plt.title("Confusion Matrix",fontsize=15)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    #Calculate Metrics
    acc=accuracy_score(Y_test,Y_pred)
    mse=mean_squared_error(Y_test,Y_pred)
    precision, recall, fscore, train_support = score(Y_test, Y_pred, pos_label=1, average='binary')
    print('Precision: {} \nRecall: {} \nF1-Score: {} \nAccuracy: {} %\nMean Square Error: {}'.format(
        round(precision, 3), round(recall, 3), round(fscore,3), round((acc*100),3), round((mse),3)))

# %%
#Model Training and Prediction

#Data Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

#Basic Models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
import time

#Metrics (Computation)
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")

# %%
#Data Splitting and scaling:
#We will split the data into training and testing sets using train_test_split from sklearn.preprocessing. 
#After splitting we will scale our data using the MinMax scaler before using it for training our model.

# %%
## Trial and Error revealed that not considering Age column improves accuracy

x = df[['ejection_fraction', 'serum_creatinine', 'serum_sodium', 'time']]
y = df['DEATH_EVENT']

#Spliting data into training and testing data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=65)

# %%
feature_df=df[['age','anaemia','creatinine_phosphokinase','diabetes','ejection_fraction','high_blood_pressure','platelets','serum_creatinine','serum_sodium','sex','smoking','time']]
X=np.asarray(feature_df)
Y=y=np.asarray(df['DEATH_EVENT'])

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
#LOGISTIC REGRESSION

import time
#Build Model
start = time.time()

model_Log= LogisticRegression(random_state=1)
model_Log.fit(X_train,Y_train)
Y_pred= model_Log.predict(X_test)

end=time.time()

model_Log_time=end-start
model_Log_accuracy=round(accuracy_score(Y_test,Y_pred), 4)*100 # Accuracy

print(f"Execution time of model: {round((model_Log_time),5)} seconds\n")
#Plot and compute metrics
compute(Y_pred,Y_test)
# Out:
# Execution time of model: 0.01809 seconds
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# Accuracy: 65.0 %
# Mean Square Error: 0.35

# %%
#DECISION TREE CLASSIFIER

#Build Model
start=time.time()

model_tree=DecisionTreeClassifier(random_state=10,criterion="gini",max_depth=100)
model_tree.fit(X_train,Y_train)
Y_pred=model_tree.predict(X_test)

end=time.time()

model_tree_time=end-start
model_tree_accuracy=round(accuracy_score(Y_test,Y_pred), 4)*100 # Accuracy

print(f"Execution time of model: {round((model_tree_time),5)} seconds")
#Plot and compute metric
compute(Y_pred,Y_test)
# Out:
# Execution time of model: 0.00612 seconds
# Precision: 0.37
# Recall: 0.476
# F1-Score: 0.417
# Accuracy: 53.333 %
# Mean Square Error: 0.467

# %%
#NAIVE BAYES

e_gnb=np.zeros(100)
params_NB = np.logspace(0,-9, num=100)
for i in range(0,len(params_NB)):
    gnb_model = GaussianNB(var_smoothing=params_NB[i])
    gnb_model.fit(X_train, y_train)
    yh_gnb=gnb_model.predict(X_test)
    e_gnb[i]=accuracy_score(y_test, yh_gnb)
    
print("Naive Bayes Prediction Accuracy Score: ",np.round(e_gnb.max(),3),' with Smoothing = ',params_NB[e_gnb.argmax()])
plt.plot(params_NB,e_gnb,'.-')
plt.plot(params_NB[e_gnb.argmax()],e_gnb.max(),'or')
plt.title('Naive Bayes Accuracy Score')
plt.xscale('log')
plt.xlabel('Var Smoothing')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Naive Bayes Prediction Accuracy Score:  0.833  with Smoothing =  2.310129700083158e-09

# %%
#SUPPORT VECTOR MACHINE

#Build Model
start=time.time()

model_svm=SVC(kernel="rbf")
model_svm.fit(X_train,Y_train)
Y_pred=model_svm.predict(X_test)

end=time.time()

model_svm_time=end-start
model_svm_accuracy=round(accuracy_score(Y_test,Y_pred), 4)*100 # Accuracy

print(f"Execution time of model: {round((model_svm_time),5)} seconds")
#Plot and compute metric
compute(Y_pred,Y_test)
# Out:
# Execution time of model: 0.01052 seconds
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# Accuracy: 65.0 %
# Mean Square Error: 0.35

# %%
accuracies={"Logistic regression": model_Log_accuracy,
            "SVM": model_svm_accuracy,
            "Decision Tree": model_tree_accuracy,
            "Naive Bayes":  e_gnb[i]}

acc_list=accuracies.items()
k,v = zip(*acc_list) 
temp=pd.DataFrame(index=k,data=v,columns=["Accuracy"])
temp.sort_values(by=["Accuracy"],ascending=False,inplace=True)

#Plot accuracy for different models
plt.figure(figsize=(20,7))
ACC=sns.barplot(y=temp.index,x=temp["Accuracy"],label="Accuracy",edgecolor="black",linewidth=3,orient="h",palette="twilight_r")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy Comparison")
plt.xlim(80,98)

ACC.spines['left'].set_linewidth(3)
for w in ['right', 'top', 'bottom']:
    ACC.spines[w].set_visible(False)
    
#Write text on barplots
k=0
for ACC in ACC.patches:
    width = ACC.get_width()
    plt.text(width+0.1, (ACC.get_y() + ACC.get_height()-0.3),s="{}%".format(temp["Accuracy"][k]),fontname = 'monospace', fontsize = 14, color = 'black') 
    k+=1
    plt.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %%
print(f'Linear Regression: {model_Log_accuracy}%\nDecision Tree Classifier: {model_tree_accuracy}%\nSupport Vector Machine: {model_svm_accuracy}%\nNaive Bayes:{e_gnb[i]}%')
# Out:
# Linear Regression: 65.0%
# Decision Tree Classifier: 53.33%
# Support Vector Machine: 65.0%
# Naive Bayes:0.8333333333333334%

# %%
 pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Heart Prediction using ANN(Artificial Neural Network)-------------------- Deep Learning

# Importing the libraries


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import callbacks

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
sns.set_theme(style="white")

# %%
df.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.834114     11.894806     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# ...

# %%
#Split Data into Train and Test

X = df.drop(["DEATH_EVENT"], axis=1)
y = df["DEATH_EVENT"]
col_names = X.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (224, 12)
# (75, 12)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_df = pd.DataFrame(X_train, columns=col_names)

# %%
X_df
# Out:
#           age   anaemia  creatinine_phosphokinase  diabetes  \
# 0    1.202429 -0.866025                  0.085743  1.197824
# 1    1.202429  1.154701                 -0.401750  1.197824
# 2   -1.581881  1.154701                 -0.353208  1.197824
# 3   -1.328762 -0.866025                  1.516206  1.197824
# 4   -0.906897  1.154701                 -0.486442  1.197824
# ..        ...       ...                       ...       ...
# 219 -0.004106  1.154701                 -0.455457  1.197824
# 220 -0.231913 -0.866025                 -0.010310  1.197824
# 221 -0.485032 -0.866025                  0.161139 -0.834847
# 222 -1.413135 -0.866025                 -0.010310  1.197824
# 223  1.624294 -0.866025                  0.316063 -0.834847
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0             1.847391            -0.730922   0.022648          0.032839
# 1            -0.046896             1.368136   0.210572         -0.778854
# ...

# %%
#Creating ANN Model

#Model 1

#*Using early_stopping
#*4 Dense, 2 Dropout
#*500 epochs (because there is early_stopping)

# %%
early_stopping = callbacks.EarlyStopping(min_delta=0.001, patience=20, restore_best_weights=True)

# %%
model = Sequential()

# %%
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                208
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense_3 (Dense)             (None, 1)                 5
#
# ...
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
pip install pydot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
learning_rate = .001
adam0 = Adam(learning_rate = learning_rate)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model_history = model.fit(X_train, y_train, batch_size = 32, epochs = 500, callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 39ms/step - loss: 0.6926 - accuracy: 0.7095 - val_loss: 0.6916 - val_accuracy: 0.7556
# Epoch 2/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6916 - accuracy: 0.6983 - val_loss: 0.6901 - val_accuracy: 0.7556
# Epoch 3/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6904 - accuracy: 0.6983 - val_loss: 0.6885 - val_accuracy: 0.7556
# Epoch 4/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.6983 - val_loss: 0.6870 - val_accuracy: 0.7556
# Epoch 5/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.6983 - val_loss: 0.6854 - val_accuracy: 0.7556
# Epoch 6/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6866 - accuracy: 0.6983 - val_loss: 0.6836 - val_accuracy: 0.7556
# Epoch 7/500
# ...

# %%
val_accuracy = np.mean(model_history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 75.53%

# %%
h_df = pd.DataFrame(model_history.history)

# %%
h_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.692631  0.709497  0.691620      0.755556
# 1   0.691555  0.698324  0.690056      0.755556
# 2   0.690366  0.698324  0.688517      0.755556
# 3   0.689117  0.698324  0.687020      0.755556
# 4   0.687940  0.698324  0.685358      0.755556
# ..       ...       ...       ...           ...
# 72  0.378133  0.804469  0.413914      0.755556
# 73  0.394635  0.770950  0.413971      0.733333
# 74  0.384475  0.759777  0.413948      0.733333
# 75  0.378066  0.776536  0.413501      0.733333
# 76  0.369757  0.787709  0.415245      0.733333
#
# [77 rows x 4 columns]

# %%
history_df = pd.DataFrame(model_history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(model_history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
#confusion matrix
cf_matrix
# Out:
# array([[39,  5],
#        [18, 13]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.89      0.77        44
#            1       0.72      0.42      0.53        31
#
#     accuracy                           0.69        75
#    macro avg       0.70      0.65      0.65        75
# weighted avg       0.70      0.69      0.67        75

# %%
#Model 2


early_stopping2 = callbacks.EarlyStopping(min_delta=0.001, patience=20, restore_best_weights=True)

# %%
model2 = Sequential()

# %%
model2.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model2.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model2.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model2.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 64)                832
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 8)                 136
#
#  dense_8 (Dense)             (None, 4)                 36
#
#  dropout_3 (Dropout)         (None, 4)                 0
#
#  dense_9 (Dense)             (None, 1)                 5
#
# ...
# Total params: 3,617
# Trainable params: 3,617
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model2, to_file='model2.png', show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model_history2 = model2.fit(X_train, y_train, batch_size = 32, epochs = 500, callbacks=[early_stopping2], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 34ms/step - loss: 0.6927 - accuracy: 0.6816 - val_loss: 0.6916 - val_accuracy: 0.7556
# Epoch 2/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6915 - accuracy: 0.6983 - val_loss: 0.6902 - val_accuracy: 0.7556
# Epoch 3/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6904 - accuracy: 0.6983 - val_loss: 0.6886 - val_accuracy: 0.7556
# Epoch 4/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6892 - accuracy: 0.6983 - val_loss: 0.6871 - val_accuracy: 0.7556
# Epoch 5/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6880 - accuracy: 0.6983 - val_loss: 0.6857 - val_accuracy: 0.7556
# Epoch 6/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6870 - accuracy: 0.6983 - val_loss: 0.6842 - val_accuracy: 0.7556
# Epoch 7/500
# ...

# %%
val_accuracy2 = np.mean(model_history2.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy2*100))
# Out:
# val_accuracy: 75.81%

# %%
h_df2 = pd.DataFrame(model_history2.history)

# %%
h_df2
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.692659  0.681564  0.691649      0.755556
# 1   0.691487  0.698324  0.690169      0.755556
# 2   0.690420  0.698324  0.688648      0.755556
# 3   0.689234  0.698324  0.687140      0.755556
# 4   0.688040  0.698324  0.685675      0.755556
# ..       ...       ...       ...           ...
# 56  0.292679  0.860335  0.508404      0.733333
# 57  0.267399  0.871508  0.507185      0.755556
# 58  0.303965  0.888268  0.513000      0.777778
# 59  0.255401  0.888268  0.524925      0.733333
# 60  0.294090  0.888268  0.526247      0.777778
#
# [61 rows x 4 columns]

# %%
history_df2 = pd.DataFrame(model_history2.history)

plt.plot(history_df2.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df2.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df2 = pd.DataFrame(model_history2.history)

plt.plot(history_df2.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df2.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred2 = model2.predict(X_test)
y_pred2 = (y_pred2 > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
cmap2 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix2 = confusion_matrix(y_test, y_pred2)
sns.heatmap(cf_matrix2/np.sum(cf_matrix2), cmap = cmap2, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
cf_matrix2
# Out:
# array([[40,  4],
#        [19, 12]], dtype=int64)

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.91      0.78        44
#            1       0.75      0.39      0.51        31
#
#     accuracy                           0.69        75
#    macro avg       0.71      0.65      0.64        75
# weighted avg       0.71      0.69      0.67        75

# %%
#MODEL 3



model3 = Sequential()

# %%
model3.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model3.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model3.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 32)                416
#
#  dense_11 (Dense)            (None, 16)                528
#
#  dense_12 (Dense)            (None, 1)                 17
#
# ...
# Total params: 961
# Trainable params: 961
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model3, to_file='model3.png', show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model3.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model_history3 = model3.fit(X_train, y_train, batch_size = 32, epochs = 100, validation_split=0.2)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 32ms/step - loss: 0.6925 - accuracy: 0.6536 - val_loss: 0.6911 - val_accuracy: 0.7556
# Epoch 2/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6906 - accuracy: 0.6983 - val_loss: 0.6888 - val_accuracy: 0.7556
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6884 - accuracy: 0.6983 - val_loss: 0.6859 - val_accuracy: 0.7556
# Epoch 4/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6852 - accuracy: 0.6983 - val_loss: 0.6821 - val_accuracy: 0.7556
# Epoch 5/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6812 - accuracy: 0.6983 - val_loss: 0.6771 - val_accuracy: 0.7556
# Epoch 6/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6751 - accuracy: 0.6983 - val_loss: 0.6704 - val_accuracy: 0.7556
# Epoch 7/100
# ...

# %%
val_accuracy3 = np.mean(model_history3.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy3*100))
# Out:
# val_accuracy: 75.56%

# %%
h_df3 = pd.DataFrame(model_history3.history)

# %%
h_df3
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.692520  0.653631  0.691150      0.755556
# 1   0.690632  0.698324  0.688821      0.755556
# 2   0.688366  0.698324  0.685885      0.755556
# 3   0.685237  0.698324  0.682118      0.755556
# 4   0.681171  0.698324  0.677099      0.755556
# ..       ...       ...       ...           ...
# 95  0.088935  0.983240  0.807697      0.800000
# 96  0.086948  0.983240  0.814048      0.777778
# 97  0.085569  0.983240  0.816128      0.755556
# 98  0.084026  0.988827  0.823369      0.777778
# 99  0.081625  0.988827  0.832957      0.777778
#
# [100 rows x 4 columns]

# %%
history_df3 = pd.DataFrame(model_history3.history)

plt.plot(history_df3.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df3.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df3 = pd.DataFrame(model_history3.history)

plt.plot(history_df3.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df3.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred3 = model3.predict(X_test)
y_pred3 = (y_pred3 > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 1ms/step

# %%
cmap3 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix3 = confusion_matrix(y_test, y_pred3)
sns.heatmap(cf_matrix3/np.sum(cf_matrix), cmap = cmap3, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
cf_matrix3
# Out:
# array([[40,  4],
#        [14, 17]], dtype=int64)

# %%
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82        44
#            1       0.81      0.55      0.65        31
#
#     accuracy                           0.76        75
#    macro avg       0.78      0.73      0.74        75
# weighted avg       0.77      0.76      0.75        75

# %%
#Thank You!
